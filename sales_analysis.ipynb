# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("sales_data.csv")

print(df)
# Out:
#          Date   Product  Quantity  Price  Total_Sales
# 0  2025-01-05    Laptop         2    800         1600
# 1  2025-01-07    Laptop         1    800          800
# 2  2025-01-08     Mouse         5     20          100
# 3  2025-02-01  Keyboard         3     50          150
# 4  2025-02-03    Laptop         4    800         3200
# 5  2025-02-05     Mouse         6     20          120
# 6  2025-03-01  Keyboard         2     50          100
# 7  2025-03-02    Laptop         3    800         2400
# 8  2025-03-05     Mouse         7     20          140

# %%
sales_by_product = df.groupby("Product")["Total_Sales"].sum()
print("\nTotal Sales by Product:\n", sales_by_product)
# Out:
# Total Sales by Product:
#  Product
# Keyboard     250
# Laptop      8000
# Mouse        360
# Name: Total_Sales, dtype: int64

# %%
sales_by_product.plot(kind='bar', title="Total Sales by Product", color='skyblue')
plt.ylabel("Sales Amount ($)")
plt.show()
